# %%
import pandas as pd
import numpy as np
import seaborn
import scipy
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('gapminder.csv', low_memory = False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               213 non-null    object
#  1   incomeperperson       213 non-null    object
#  2   alcconsumption        213 non-null    object
#  3   armedforcesrate       213 non-null    object
#  4   breastcancerper100th  213 non-null    object
#  5   co2emissions          213 non-null    object
#  6   femaleemployrate      213 non-null    object
#  7   hivrate               213 non-null    object
#  8   internetuserate       213 non-null    object
#  9   lifeexpectancy        213 non-null    object
#  10  oilperperson          213 non-null    object
#  11  polityscore           213 non-null    object
#  12  relectricperperson    213 non-null    object
#  13  suicideper100th       213 non-null    object
#  14  employrate            213 non-null    object
#  15  urbanrate             213 non-null    object
# dtypes: object(16)
# memory usage: 26.8+ KB

# %%
data.head(20)
# Out:
#                 country   incomeperperson alcconsumption armedforcesrate  \
# 0           Afghanistan                              .03        .5696534
# 1               Albania  1914.99655094922           7.29       1.0247361
# 2               Algeria  2231.99333515006            .69        2.306817
# 3               Andorra  21943.3398976022          10.17
# 4                Angola  1381.00426770244           5.57       1.4613288
# 5   Antigua and Barbuda  11894.4640745081           8.17
# 6             Argentina  10749.4192379463           9.35         .560987
# 7               Armenia  1326.74175718861          13.66       2.6184384
# 8                 Aruba
# 9             Australia    25249.98606148          10.21        .4862799
# 10              Austria  26692.9841066319           12.4        .8155798
# 11           Azerbaijan  2344.89691619809          13.34       1.9767462
# 12              Bahamas  19630.5405471267           8.65        .5452863
# 13              Bahrain  12505.2125447354           4.19       5.2311429
# 14           Bangladesh  558.062876627297            .17        .2878915
# 15             Barbados  9243.58705259742           6.42        .6639555
# 16              Belarus  2737.67037938365          18.85       3.7119299
# 17              Belgium  24496.0482640925          10.41        .8156477
# 18               Belize    3545.652173906           5.92        .7583556
# 19                Benin  377.039699461343           2.08        .2233986
#
#    breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# 0                  26.8          75944000  25.6000003814697
# 1                  57.4  223747333.333333  42.0999984741211
# 2                  23.5  2932108666.66667  31.7000007629394      .1
# 3
# 4                  23.1         248358000  69.4000015258789       2
# 5                                16225000
# 6                  73.9        5872119000  45.9000015258789      .5
# 7                  51.6  51219666.6666667  34.2000007629394      .1
# 8                                35871000
# 9                  83.2  12970092666.6667  54.5999984741211      .1
# 10                 70.5  4466084333.33333  49.7000007629394      .3
# 11                 31.5  511107666.666667  56.2000007629394      .1
# 12                 54.4         137555000  60.7000007629394     3.1
# 13                 40.2  503994333.333333  30.2000007629394
# 14                 16.6         598774000  53.5999984741211     .06
# 15                 62.5  36160666.6666667  60.2999992370606     1.4
# 16                   36  999874333.333333  48.5999984741211      .3
# 17                   92  10897025333.3333  41.7000007629394      .2
# 18                 29.8          14058000  38.7999992370606     2.3
# 19                 28.1          37950000  58.2000007629394     1.2
#
#      internetuserate lifeexpectancy      oilperperson polityscore  \
# 0   3.65412162280064         48.673                             0
# 1   44.9899469578783         76.918                             9
# 2   12.5000733055148         73.131   .42009452521537           2
# 3                 81
# 4   9.99995388324075         51.093                            -2
# 5   80.6454545454545
# 6   36.0003349500148         75.901  .635943800978195           8
# 7   44.0010245795602         74.241                             5
# 8   41.8008888888889         75.246
# 9   75.8956537961344         81.907  1.91302610912404          10
# 10  72.7315755423123         80.854  1.54879096611674          10
# 11  46.6797015683676         70.739   .35917260997566          -7
# 12  42.9845801749271          75.62
# 13  54.9928090332805         75.057                            -7
# 14  3.70000325975843         68.944   .03228146619272           5
# 15   70.028599270073         76.835
# 16  32.0521439093783         70.349  .687828079664248          -7
# 17  73.7339344713656         80.009                             8
# 18  12.6457333333333         76.072
# 19  3.12996180338983         56.081                             7
#
#    relectricperperson   suicideper100th        employrate urbanrate
# 0                      6.68438529968262  55.7000007629394     24.04
# 1    636.341383366604  7.69932985305786  51.4000015258789     46.72
# 2    590.509814347428   4.8487696647644              50.5     65.22
# 3                      5.36217880249023                       88.92
# 4    172.999227388199  14.5546770095825  75.6999969482422      56.7
# 5                      2.16184329986572                       30.46
# 6    768.428299701347          7.765584  58.4000015258789        92
# 7    603.763057563433  3.74158787727356  40.0999984741211     63.86
# 8                                                             46.78
# 9    2825.39109539914   8.4700301251191              61.5     88.74
# 10   2068.12330899163          13.09437  57.0999984741211     67.16
# 11   921.562110759901  1.38096463680267  60.9000015258789     51.92
# 12                      3.3744158744812  66.5999984741211      83.7
# 13    7314.3556367342  4.41499042510986  60.4000015258789     88.52
# 14   68.1152285841314  14.5383567810059  68.0999984741211     27.14
# 15                     3.10860252380371  66.9000015258789     39.84
# 16   614.907287211113  26.8746902951384  53.4000015258789     73.46
# 17   1920.96221521997          15.95385  48.5999984741211     97.36
# 18                     9.38879585266113  56.7999992370606      51.7
# 19   38.2229433578852  6.05773973464966  71.5999984741211      41.2

# %%
data['internetuserate'] = pd.to_numeric(data['internetuserate'], errors = 'coerce')
data['urbanrate'] = pd.to_numeric(data['urbanrate'], errors = 'coerce')
data['incomeperperson'] = pd.to_numeric(data['incomeperperson'], errors = 'coerce')

# %%
scat1 = seaborn.regplot(x = "urbanrate", y="internetuserate", fit_reg = True, data = data)
plt.xlabel('Urban Rate')
plt.ylabel('Internet Use Rate')
plt.title('Scatterplot for the Association Between Urban Rate and Internet Use Rate')
# Out:
# Text(0.5, 1.0, 'Scatterplot for the Association Between Urban Rate and Internet Use Rate')

# %%
scat2 = seaborn.regplot(x = "incomeperperson", y="internetuserate", data = data)
plt.xlabel('Income per Person')
plt.ylabel('Internet Use Rate')
plt.title('Scatterplot for the Association Between Income per Person and Internet Use Rate')
# Out:
# Text(0.5, 1.0, 'Scatterplot for the Association Between Income per Person and Internet Use Rate')

# %%
data_clean = data.dropna()

# %%
data_clean
# Out:
#                  country  incomeperperson alcconsumption armedforcesrate  \
# 1                Albania      1914.996551           7.29       1.0247361
# 2                Algeria      2231.993335            .69        2.306817
# 3                Andorra     21943.339898          10.17
# 4                 Angola      1381.004268           5.57       1.4613288
# 5    Antigua and Barbuda     11894.464075           8.17
# ..                   ...              ...            ...             ...
# 207            Venezuela      5528.363114            7.6        .9040245
# 208              Vietnam       722.807559           3.91       1.0853671
# 210          Yemen, Rep.       610.357367             .2       2.3162346
# 211               Zambia       432.226337           3.56        .3413352
# 212             Zimbabwe       320.771890           4.96       1.0327854
#
#     breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# 1                   57.4  223747333.333333  42.0999984741211
# 2                   23.5  2932108666.66667  31.7000007629394      .1
# 3
# 4                   23.1         248358000  69.4000015258789       2
# 5                                 16225000
# ..                   ...               ...               ...     ...
# 207                 34.3        5418886000  45.7999992370606
# 208                 16.2        1425435000  67.5999984741211      .4
# 210                 35.1  234864666.666667  20.2999992370605
# 211                   13  132025666.666667              53.5    13.5
# 212                   19  590219666.666666  58.0999984741211    14.3
#
#      internetuserate lifeexpectancy      oilperperson polityscore  \
# 1          44.989947         76.918                             9
# 2          12.500073         73.131   .42009452521537           2
# 3          81.000000
# 4           9.999954         51.093                            -2
# 5          80.645455
# ..               ...            ...               ...         ...
# 207        35.850437         74.402  1.21463677339747          -3
# 208        27.851822         75.181                            -7
# 210        12.349750         65.493                            -2
# 211        10.124986         49.025                             7
# 212        11.500415         51.384                             1
#
#     relectricperperson   suicideper100th        employrate  urbanrate
# 1     636.341383366604  7.69932985305786  51.4000015258789      46.72
# 2     590.509814347428   4.8487696647644              50.5      65.22
# 3                       5.36217880249023                        88.92
# 4     172.999227388199  14.5546770095825  75.6999969482422      56.70
# 5                       2.16184329986572                        30.46
# ..                 ...               ...               ...        ...
# 207   969.004338760415           4.11962  59.9000015258789      93.32
# 208   302.725654656034  11.6533222198486                71      27.84
# 210    130.05783139719  6.26578903198242                39      30.64
# 211   168.623030511023  12.0190362930298                61      35.42
# 212   297.883200408304  13.9052667617798  66.8000030517578      37.34
#
# [182 rows x 16 columns]

# %%
print ('association between urbanrate and internetuserate')
print (scipy.stats.pearsonr(data_clean['urbanrate'], data_clean['internetuserate']))
# Out:
# association between urbanrate and internetuserate
# (0.6244640029489792, 4.540316299447003e-21)

# %%
print ('association between incomeperperson and internetuserate')
print (scipy.stats.pearsonr(data_clean['incomeperperson'], data_clean['internetuserate']))
# Out:
# association between incomeperperson and internetuserate
# (0.7507274333051273, 3.067338031233027e-34)
